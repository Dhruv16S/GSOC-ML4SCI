# %% [markdown]
# # Task 1: Data Retrieval and Parsing
#
# Retrieving and plotting Gamma Ray Spectrometer(GRS) data. The data is collected for a duration of 18 months at an interval of 32 seconds from 1998 to 1999 at an altitude of ~30km and ~100km.

# %%
# Importing libraries to download required data
import urllib.request
import time
import struct
import pandas as pd

# %% [markdown]
# # Retrieving the corresponding .dat and .lbl file
#
# Before parsing through the .dat files which hold the correspoding GRS data, the files are downloaded from the following url https://pds-geosciences.wustl.edu/lunar/lp-l-grs-3-rdr-v1/lp_2xxx/grs/ using the **urllib.request** module within Python. The files are stored locally, following the naming convention **{year}_{day}_grs.dat** and **{year}_{day}_grs.lbl**
#
# The datasets for the years 1998 and 1999 have been downloaded separately inorder to minimize the overhead.

# %%
# Downloading GRS data from the specified URL for the year 1998

url = 'https://pds-geosciences.wustl.edu/lunar/lp-l-grs-3-rdr-v1/lp_2xxx/grs/'

start = time.time()
data_not_found = 0
label_not_found = 0

for year in range(1998, 1999):
    for day in range(1, 367):
        if day < 100:
            if day < 10:
                temp_day = "00" + str(day)
            else:
                temp_day = "0" + str(day)
            data_file_name = f'{year}_{temp_day}_grs.dat'
            label_file_name = f'{year}_{temp_day}_grs.lbl'
        else:
            data_file_name = f'{year}_{day}_grs.dat'
            label_file_name = f'{year}_{day}_grs.lbl'
        url_data = url + data_file_name
        url_label = url + label_file_name
        try:
            urllib.request.urlretrieve(url_data, data_file_name)
        except:
            print(f"Data file for {data_file_name} could not be retrieved.")
            data_not_found += 1 
        try:
            urllib.request.urlretrieve(url_label, label_file_name)
        except:
            print(f"Label file for {label_file_name} could not be retrieved.")
            label_not_found += 1

end = time.time()

print("Total time taken to retrive all data and label files: {:.4f} seconds".format(end-start))
print(f"Total .dat files not found {data_not_found}")
print(f"Total .lbl files not found {label_not_found}")
# Out:
# Data file for 1998_001_grs.dat could not be retrieved.
# Label file for 1998_001_grs.lbl could not be retrieved.
# Data file for 1998_002_grs.dat could not be retrieved.
# Label file for 1998_002_grs.lbl could not be retrieved.
# Data file for 1998_003_grs.dat could not be retrieved.
# Label file for 1998_003_grs.lbl could not be retrieved.
# Data file for 1998_004_grs.dat could not be retrieved.
# Label file for 1998_004_grs.lbl could not be retrieved.
# Data file for 1998_005_grs.dat could not be retrieved.
# Label file for 1998_005_grs.lbl could not be retrieved.
# Data file for 1998_006_grs.dat could not be retrieved.
# Label file for 1998_006_grs.lbl could not be retrieved.
# Data file for 1998_007_grs.dat could not be retrieved.
# Label file for 1998_007_grs.lbl could not be retrieved.
# Data file for 1998_008_grs.dat could not be retrieved.
# Label file for 1998_008_grs.lbl could not be retrieved.
# Data file for 1998_009_grs.dat could not be retrieved.
# Label file for 1998_009_grs.lbl could not be retrieved.
# Data file for 1998_010_grs.dat could not be retrieved.
# Label file for 1998_010_grs.lbl could not be retrieved.
# Data file for 1998_011_grs.dat could not be retrieved.
# Label file for 1998_011_grs.lbl could not be retrieved.
# Data file for 1998_012_grs.dat could not be retrieved.
# Label file for 1998_012_grs.lbl could not be retrieved.
# Data file for 1998_013_grs.dat could not be retrieved.
# Label file for 1998_013_grs.lbl could not be retrieved.
# Data file for 1998_014_grs.dat could not be retrieved.
# Label file for 1998_014_grs.lbl could not be retrieved.
# Data file for 1998_015_grs.dat could not be retrieved.
# Label file for 1998_015_grs.lbl could not be retrieved.
# Label file for 1998_034_grs.lbl could not be retrieved.
# Data file for 1998_048_grs.dat could not be retrieved.
# Data file for 1998_058_grs.dat could not be retrieved.
# Label file for 1998_075_grs.lbl could not be retrieved.
# Data file for 1998_087_grs.dat could not be retrieved.
# Label file for 1998_104_grs.lbl could not be retrieved.
# Data file for 1998_111_grs.dat could not be retrieved.
# Label file for 1998_111_grs.lbl could not be retrieved.
# Data file for 1998_112_grs.dat could not be retrieved.
# Label file for 1998_112_grs.lbl could not be retrieved.
# Data file for 1998_113_grs.dat could not be retrieved.
# Label file for 1998_113_grs.lbl could not be retrieved.
# Data file for 1998_114_grs.dat could not be retrieved.
# Label file for 1998_114_grs.lbl could not be retrieved.
# Data file for 1998_115_grs.dat could not be retrieved.
# Label file for 1998_115_grs.lbl could not be retrieved.
# Data file for 1998_120_grs.dat could not be retrieved.
# Label file for 1998_120_grs.lbl could not be retrieved.
# Data file for 1998_121_grs.dat could not be retrieved.
# Label file for 1998_121_grs.lbl could not be retrieved.
# Data file for 1998_122_grs.dat could not be retrieved.
# Label file for 1998_122_grs.lbl could not be retrieved.
# Data file for 1998_123_grs.dat could not be retrieved.
# Label file for 1998_123_grs.lbl could not be retrieved.
# Data file for 1998_127_grs.dat could not be retrieved.
# Label file for 1998_127_grs.lbl could not be retrieved.
# Data file for 1998_130_grs.dat could not be retrieved.
# Label file for 1998_130_grs.lbl could not be retrieved.
# Data file for 1998_169_grs.dat could not be retrieved.
# Label file for 1998_169_grs.lbl could not be retrieved.
# Data file for 1998_184_grs.dat could not be retrieved.
# Data file for 1998_201_grs.dat could not be retrieved.
# Data file for 1998_235_grs.dat could not be retrieved.
# Label file for 1998_235_grs.lbl could not be retrieved.
# Data file for 1998_236_grs.dat could not be retrieved.
# Label file for 1998_236_grs.lbl could not be retrieved.
# Data file for 1998_237_grs.dat could not be retrieved.
# Label file for 1998_237_grs.lbl could not be retrieved.
# Data file for 1998_238_grs.dat could not be retrieved.
# Label file for 1998_238_grs.lbl could not be retrieved.
# Data file for 1998_239_grs.dat could not be retrieved.
# Label file for 1998_239_grs.lbl could not be retrieved.
# Data file for 1998_240_grs.dat could not be retrieved.
# Label file for 1998_240_grs.lbl could not be retrieved.
# Data file for 1998_241_grs.dat could not be retrieved.
# Label file for 1998_241_grs.lbl could not be retrieved.
# Data file for 1998_242_grs.dat could not be retrieved.
# Label file for 1998_242_grs.lbl could not be retrieved.
# Label file for 1998_246_grs.lbl could not be retrieved.
# Data file for 1998_274_grs.dat could not be retrieved.
# Label file for 1998_274_grs.lbl could not be retrieved.
# Data file for 1998_275_grs.dat could not be retrieved.
# Label file for 1998_275_grs.lbl could not be retrieved.
# Data file for 1998_276_grs.dat could not be retrieved.
# Label file for 1998_276_grs.lbl could not be retrieved.
# Label file for 1998_278_grs.lbl could not be retrieved.
# Data file for 1998_279_grs.dat could not be retrieved.
# Label file for 1998_279_grs.lbl could not be retrieved.
# Label file for 1998_282_grs.lbl could not be retrieved.
# Data file for 1998_292_grs.dat could not be retrieved.
# Label file for 1998_292_grs.lbl could not be retrieved.
# Data file for 1998_301_grs.dat could not be retrieved.
# Label file for 1998_301_grs.lbl could not be retrieved.
# Data file for 1998_310_grs.dat could not be retrieved.
# Label file for 1998_310_grs.lbl could not be retrieved.
# Data file for 1998_311_grs.dat could not be retrieved.
# Label file for 1998_311_grs.lbl could not be retrieved.
# Data file for 1998_312_grs.dat could not be retrieved.
# Label file for 1998_312_grs.lbl could not be retrieved.
# Data file for 1998_319_grs.dat could not be retrieved.
# Label file for 1998_319_grs.lbl could not be retrieved.
# Data file for 1998_320_grs.dat could not be retrieved.
# Label file for 1998_320_grs.lbl could not be retrieved.
# Data file for 1998_321_grs.dat could not be retrieved.
# Label file for 1998_321_grs.lbl could not be retrieved.
# Data file for 1998_322_grs.dat could not be retrieved.
# Label file for 1998_322_grs.lbl could not be retrieved.
# Label file for 1998_331_grs.lbl could not be retrieved.
# Label file for 1998_341_grs.lbl could not be retrieved.
# Label file for 1998_346_grs.lbl could not be retrieved.
# Data file for 1998_366_grs.dat could not be retrieved.
# Label file for 1998_366_grs.lbl could not be retrieved.
# Total time taken to retrive all data and label files: 2810.9223 seconds
# Total .dat files not found 54
# Total .lbl files not found 58

# %%
# Downloading GRS data from the specified URL for the year 1999

url = 'https://pds-geosciences.wustl.edu/lunar/lp-l-grs-3-rdr-v1/lp_2xxx/grs/'

start = time.time()
data_not_found = 0
label_not_found = 0

for year in range(1999, 2000):
    for day in range(1, 367):
        if day < 100:
            if day < 10:
                temp_day = "00" + str(day)
            else:
                temp_day = "0" + str(day)
            data_file_name = f'{year}_{temp_day}_grs.dat'
            label_file_name = f'{year}_{temp_day}_grs.lbl'
        else:
            data_file_name = f'{year}_{day}_grs.dat'
            label_file_name = f'{year}_{day}_grs.lbl'
        url_data = url + data_file_name
        url_label = url + label_file_name
        try:
            urllib.request.urlretrieve(url_data, data_file_name)
        except:
            print(f"Data file for {data_file_name} could not be retrieved.")
            data_not_found += 1 
        try:
            urllib.request.urlretrieve(url_label, label_file_name)
        except:
            print(f"Label file for {label_file_name} could not be retrieved.")
            label_not_found += 1

end = time.time()

print("Total time taken to retrive all data and label files: {:.4f} seconds".format(end-start))
print(f"Total .dat files not found {data_not_found}")
print(f"Total .lbl files not found {label_not_found}")
# Out:
# Data file for 1999_021_grs.dat could not be retrieved.
# Label file for 1999_021_grs.lbl could not be retrieved.
# Data file for 1999_022_grs.dat could not be retrieved.
# Label file for 1999_022_grs.lbl could not be retrieved.
# Data file for 1999_023_grs.dat could not be retrieved.
# Label file for 1999_023_grs.lbl could not be retrieved.
# Data file for 1999_024_grs.dat could not be retrieved.
# Label file for 1999_024_grs.lbl could not be retrieved.
# Label file for 1999_033_grs.lbl could not be retrieved.
# Label file for 1999_040_grs.lbl could not be retrieved.
# Label file for 1999_055_grs.lbl could not be retrieved.
# Label file for 1999_059_grs.lbl could not be retrieved.
# Label file for 1999_073_grs.lbl could not be retrieved.
# Label file for 1999_090_grs.lbl could not be retrieved.
# Data file for 1999_107_grs.dat could not be retrieved.
# Data file for 1999_115_grs.dat could not be retrieved.
# Label file for 1999_115_grs.lbl could not be retrieved.
# Data file for 1999_124_grs.dat could not be retrieved.
# Data file for 1999_125_grs.dat could not be retrieved.
# Label file for 1999_125_grs.lbl could not be retrieved.
# Data file for 1999_126_grs.dat could not be retrieved.
# Label file for 1999_126_grs.lbl could not be retrieved.
# Data file for 1999_127_grs.dat could not be retrieved.
# Label file for 1999_127_grs.lbl could not be retrieved.
# Label file for 1999_138_grs.lbl could not be retrieved.
# Data file for 1999_153_grs.dat could not be retrieved.
# Label file for 1999_153_grs.lbl could not be retrieved.
# Data file for 1999_154_grs.dat could not be retrieved.
# Label file for 1999_154_grs.lbl could not be retrieved.
# Data file for 1999_155_grs.dat could not be retrieved.
# Label file for 1999_155_grs.lbl could not be retrieved.
# Data file for 1999_156_grs.dat could not be retrieved.
# Label file for 1999_156_grs.lbl could not be retrieved.
# Data file for 1999_157_grs.dat could not be retrieved.
# Label file for 1999_157_grs.lbl could not be retrieved.
# Data file for 1999_158_grs.dat could not be retrieved.
# Label file for 1999_158_grs.lbl could not be retrieved.
# Data file for 1999_167_grs.dat could not be retrieved.
# Data file for 1999_210_grs.dat could not be retrieved.
# Label file for 1999_210_grs.lbl could not be retrieved.
# Data file for 1999_211_grs.dat could not be retrieved.
# Label file for 1999_211_grs.lbl could not be retrieved.
# Data file for 1999_212_grs.dat could not be retrieved.
# Label file for 1999_212_grs.lbl could not be retrieved.
# Data file for 1999_213_grs.dat could not be retrieved.
# Label file for 1999_213_grs.lbl could not be retrieved.
# Data file for 1999_214_grs.dat could not be retrieved.
# Label file for 1999_214_grs.lbl could not be retrieved.
# Data file for 1999_215_grs.dat could not be retrieved.
# Label file for 1999_215_grs.lbl could not be retrieved.
# Data file for 1999_216_grs.dat could not be retrieved.
# Label file for 1999_216_grs.lbl could not be retrieved.
# Data file for 1999_217_grs.dat could not be retrieved.
# Label file for 1999_217_grs.lbl could not be retrieved.
# Data file for 1999_218_grs.dat could not be retrieved.
# Label file for 1999_218_grs.lbl could not be retrieved.
# Data file for 1999_219_grs.dat could not be retrieved.
# Label file for 1999_219_grs.lbl could not be retrieved.
# Data file for 1999_220_grs.dat could not be retrieved.
# Label file for 1999_220_grs.lbl could not be retrieved.
# Data file for 1999_221_grs.dat could not be retrieved.
# Label file for 1999_221_grs.lbl could not be retrieved.
# Data file for 1999_222_grs.dat could not be retrieved.
# Label file for 1999_222_grs.lbl could not be retrieved.
# Data file for 1999_223_grs.dat could not be retrieved.
# Label file for 1999_223_grs.lbl could not be retrieved.
# Data file for 1999_224_grs.dat could not be retrieved.
# Label file for 1999_224_grs.lbl could not be retrieved.
# Data file for 1999_225_grs.dat could not be retrieved.
# Label file for 1999_225_grs.lbl could not be retrieved.
# Data file for 1999_226_grs.dat could not be retrieved.
# Label file for 1999_226_grs.lbl could not be retrieved.
# Data file for 1999_227_grs.dat could not be retrieved.
# Label file for 1999_227_grs.lbl could not be retrieved.
# Data file for 1999_228_grs.dat could not be retrieved.
# Label file for 1999_228_grs.lbl could not be retrieved.
# Data file for 1999_229_grs.dat could not be retrieved.
# Label file for 1999_229_grs.lbl could not be retrieved.
# Data file for 1999_230_grs.dat could not be retrieved.
# Label file for 1999_230_grs.lbl could not be retrieved.
# Data file for 1999_231_grs.dat could not be retrieved.
# Label file for 1999_231_grs.lbl could not be retrieved.
# Data file for 1999_232_grs.dat could not be retrieved.
# Label file for 1999_232_grs.lbl could not be retrieved.
# Data file for 1999_233_grs.dat could not be retrieved.
# Label file for 1999_233_grs.lbl could not be retrieved.
# Data file for 1999_234_grs.dat could not be retrieved.
# Label file for 1999_234_grs.lbl could not be retrieved.
# Data file for 1999_235_grs.dat could not be retrieved.
# Label file for 1999_235_grs.lbl could not be retrieved.
# Data file for 1999_236_grs.dat could not be retrieved.
# Label file for 1999_236_grs.lbl could not be retrieved.
# Data file for 1999_237_grs.dat could not be retrieved.
# Label file for 1999_237_grs.lbl could not be retrieved.
# Data file for 1999_238_grs.dat could not be retrieved.
# Label file for 1999_238_grs.lbl could not be retrieved.
# Data file for 1999_239_grs.dat could not be retrieved.
# Label file for 1999_239_grs.lbl could not be retrieved.
# Data file for 1999_240_grs.dat could not be retrieved.
# Label file for 1999_240_grs.lbl could not be retrieved.
# Data file for 1999_241_grs.dat could not be retrieved.
# Label file for 1999_241_grs.lbl could not be retrieved.
# Data file for 1999_242_grs.dat could not be retrieved.
# Label file for 1999_242_grs.lbl could not be retrieved.
# Data file for 1999_243_grs.dat could not be retrieved.
# Label file for 1999_243_grs.lbl could not be retrieved.
# Data file for 1999_244_grs.dat could not be retrieved.
# Label file for 1999_244_grs.lbl could not be retrieved.
# Data file for 1999_245_grs.dat could not be retrieved.
# Label file for 1999_245_grs.lbl could not be retrieved.
# Data file for 1999_246_grs.dat could not be retrieved.
# Label file for 1999_246_grs.lbl could not be retrieved.
# Data file for 1999_247_grs.dat could not be retrieved.
# Label file for 1999_247_grs.lbl could not be retrieved.
# Data file for 1999_248_grs.dat could not be retrieved.
# Label file for 1999_248_grs.lbl could not be retrieved.
# Data file for 1999_249_grs.dat could not be retrieved.
# Label file for 1999_249_grs.lbl could not be retrieved.
# Data file for 1999_250_grs.dat could not be retrieved.
# Label file for 1999_250_grs.lbl could not be retrieved.
# Data file for 1999_251_grs.dat could not be retrieved.
# Label file for 1999_251_grs.lbl could not be retrieved.
# Data file for 1999_252_grs.dat could not be retrieved.
# Label file for 1999_252_grs.lbl could not be retrieved.
# Data file for 1999_253_grs.dat could not be retrieved.
# Label file for 1999_253_grs.lbl could not be retrieved.
# Data file for 1999_254_grs.dat could not be retrieved.
# Label file for 1999_254_grs.lbl could not be retrieved.
# Data file for 1999_255_grs.dat could not be retrieved.
# Label file for 1999_255_grs.lbl could not be retrieved.
# Data file for 1999_256_grs.dat could not be retrieved.
# Label file for 1999_256_grs.lbl could not be retrieved.
# Data file for 1999_257_grs.dat could not be retrieved.
# Label file for 1999_257_grs.lbl could not be retrieved.
# Data file for 1999_258_grs.dat could not be retrieved.
# Label file for 1999_258_grs.lbl could not be retrieved.
# Data file for 1999_259_grs.dat could not be retrieved.
# Label file for 1999_259_grs.lbl could not be retrieved.
# Data file for 1999_260_grs.dat could not be retrieved.
# Label file for 1999_260_grs.lbl could not be retrieved.
# Data file for 1999_261_grs.dat could not be retrieved.
# Label file for 1999_261_grs.lbl could not be retrieved.
# Data file for 1999_262_grs.dat could not be retrieved.
# Label file for 1999_262_grs.lbl could not be retrieved.
# Data file for 1999_263_grs.dat could not be retrieved.
# Label file for 1999_263_grs.lbl could not be retrieved.
# Data file for 1999_264_grs.dat could not be retrieved.
# Label file for 1999_264_grs.lbl could not be retrieved.
# Data file for 1999_265_grs.dat could not be retrieved.
# Label file for 1999_265_grs.lbl could not be retrieved.
# Data file for 1999_266_grs.dat could not be retrieved.
# Label file for 1999_266_grs.lbl could not be retrieved.
# Data file for 1999_267_grs.dat could not be retrieved.
# Label file for 1999_267_grs.lbl could not be retrieved.
# Data file for 1999_268_grs.dat could not be retrieved.
# Label file for 1999_268_grs.lbl could not be retrieved.
# Data file for 1999_269_grs.dat could not be retrieved.
# Label file for 1999_269_grs.lbl could not be retrieved.
# Data file for 1999_270_grs.dat could not be retrieved.
# Label file for 1999_270_grs.lbl could not be retrieved.
# Data file for 1999_271_grs.dat could not be retrieved.
# Label file for 1999_271_grs.lbl could not be retrieved.
# Data file for 1999_272_grs.dat could not be retrieved.
# Label file for 1999_272_grs.lbl could not be retrieved.
# Data file for 1999_273_grs.dat could not be retrieved.
# Label file for 1999_273_grs.lbl could not be retrieved.
# Data file for 1999_274_grs.dat could not be retrieved.
# Label file for 1999_274_grs.lbl could not be retrieved.
# Data file for 1999_275_grs.dat could not be retrieved.
# Label file for 1999_275_grs.lbl could not be retrieved.
# Data file for 1999_276_grs.dat could not be retrieved.
# Label file for 1999_276_grs.lbl could not be retrieved.
# Data file for 1999_277_grs.dat could not be retrieved.
# Label file for 1999_277_grs.lbl could not be retrieved.
# Data file for 1999_278_grs.dat could not be retrieved.
# Label file for 1999_278_grs.lbl could not be retrieved.
# Data file for 1999_279_grs.dat could not be retrieved.
# Label file for 1999_279_grs.lbl could not be retrieved.
# Data file for 1999_280_grs.dat could not be retrieved.
# Label file for 1999_280_grs.lbl could not be retrieved.
# Data file for 1999_281_grs.dat could not be retrieved.
# Label file for 1999_281_grs.lbl could not be retrieved.
# Data file for 1999_282_grs.dat could not be retrieved.
# Label file for 1999_282_grs.lbl could not be retrieved.
# Data file for 1999_283_grs.dat could not be retrieved.
# Label file for 1999_283_grs.lbl could not be retrieved.
# Data file for 1999_284_grs.dat could not be retrieved.
# Label file for 1999_284_grs.lbl could not be retrieved.
# Data file for 1999_285_grs.dat could not be retrieved.
# Label file for 1999_285_grs.lbl could not be retrieved.
# Data file for 1999_286_grs.dat could not be retrieved.
# Label file for 1999_286_grs.lbl could not be retrieved.
# Data file for 1999_287_grs.dat could not be retrieved.
# Label file for 1999_287_grs.lbl could not be retrieved.
# Data file for 1999_288_grs.dat could not be retrieved.
# Label file for 1999_288_grs.lbl could not be retrieved.
# Data file for 1999_289_grs.dat could not be retrieved.
# Label file for 1999_289_grs.lbl could not be retrieved.
# Data file for 1999_290_grs.dat could not be retrieved.
# Label file for 1999_290_grs.lbl could not be retrieved.
# Data file for 1999_291_grs.dat could not be retrieved.
# Label file for 1999_291_grs.lbl could not be retrieved.
# Data file for 1999_292_grs.dat could not be retrieved.
# Label file for 1999_292_grs.lbl could not be retrieved.
# Data file for 1999_293_grs.dat could not be retrieved.
# Label file for 1999_293_grs.lbl could not be retrieved.
# Data file for 1999_294_grs.dat could not be retrieved.
# Label file for 1999_294_grs.lbl could not be retrieved.
# Data file for 1999_295_grs.dat could not be retrieved.
# Label file for 1999_295_grs.lbl could not be retrieved.
# Data file for 1999_296_grs.dat could not be retrieved.
# Label file for 1999_296_grs.lbl could not be retrieved.
# Data file for 1999_297_grs.dat could not be retrieved.
# Label file for 1999_297_grs.lbl could not be retrieved.
# Data file for 1999_298_grs.dat could not be retrieved.
# Label file for 1999_298_grs.lbl could not be retrieved.
# Data file for 1999_299_grs.dat could not be retrieved.
# Label file for 1999_299_grs.lbl could not be retrieved.
# Data file for 1999_300_grs.dat could not be retrieved.
# Label file for 1999_300_grs.lbl could not be retrieved.
# Data file for 1999_301_grs.dat could not be retrieved.
# Label file for 1999_301_grs.lbl could not be retrieved.
# Data file for 1999_302_grs.dat could not be retrieved.
# Label file for 1999_302_grs.lbl could not be retrieved.
# Data file for 1999_303_grs.dat could not be retrieved.
# Label file for 1999_303_grs.lbl could not be retrieved.
# Data file for 1999_304_grs.dat could not be retrieved.
# Label file for 1999_304_grs.lbl could not be retrieved.
# Data file for 1999_305_grs.dat could not be retrieved.
# Label file for 1999_305_grs.lbl could not be retrieved.
# Data file for 1999_306_grs.dat could not be retrieved.
# Label file for 1999_306_grs.lbl could not be retrieved.
# Data file for 1999_307_grs.dat could not be retrieved.
# Label file for 1999_307_grs.lbl could not be retrieved.
# Data file for 1999_308_grs.dat could not be retrieved.
# Label file for 1999_308_grs.lbl could not be retrieved.
# Data file for 1999_309_grs.dat could not be retrieved.
# Label file for 1999_309_grs.lbl could not be retrieved.
# Data file for 1999_310_grs.dat could not be retrieved.
# Label file for 1999_310_grs.lbl could not be retrieved.
# Data file for 1999_311_grs.dat could not be retrieved.
# Label file for 1999_311_grs.lbl could not be retrieved.
# Data file for 1999_312_grs.dat could not be retrieved.
# Label file for 1999_312_grs.lbl could not be retrieved.
# Data file for 1999_313_grs.dat could not be retrieved.
# Label file for 1999_313_grs.lbl could not be retrieved.
# Data file for 1999_314_grs.dat could not be retrieved.
# Label file for 1999_314_grs.lbl could not be retrieved.
# Data file for 1999_315_grs.dat could not be retrieved.
# Label file for 1999_315_grs.lbl could not be retrieved.
# Data file for 1999_316_grs.dat could not be retrieved.
# Label file for 1999_316_grs.lbl could not be retrieved.
# Data file for 1999_317_grs.dat could not be retrieved.
# Label file for 1999_317_grs.lbl could not be retrieved.
# Data file for 1999_318_grs.dat could not be retrieved.
# Label file for 1999_318_grs.lbl could not be retrieved.
# Data file for 1999_319_grs.dat could not be retrieved.
# Label file for 1999_319_grs.lbl could not be retrieved.
# Data file for 1999_320_grs.dat could not be retrieved.
# Label file for 1999_320_grs.lbl could not be retrieved.
# Data file for 1999_321_grs.dat could not be retrieved.
# Label file for 1999_321_grs.lbl could not be retrieved.
# Data file for 1999_322_grs.dat could not be retrieved.
# Label file for 1999_322_grs.lbl could not be retrieved.
# Data file for 1999_323_grs.dat could not be retrieved.
# Label file for 1999_323_grs.lbl could not be retrieved.
# Data file for 1999_324_grs.dat could not be retrieved.
# Label file for 1999_324_grs.lbl could not be retrieved.
# Data file for 1999_325_grs.dat could not be retrieved.
# Label file for 1999_325_grs.lbl could not be retrieved.
# Data file for 1999_326_grs.dat could not be retrieved.
# Label file for 1999_326_grs.lbl could not be retrieved.
# Data file for 1999_327_grs.dat could not be retrieved.
# Label file for 1999_327_grs.lbl could not be retrieved.
# Data file for 1999_328_grs.dat could not be retrieved.
# Label file for 1999_328_grs.lbl could not be retrieved.
# Data file for 1999_329_grs.dat could not be retrieved.
# Label file for 1999_329_grs.lbl could not be retrieved.
# Data file for 1999_330_grs.dat could not be retrieved.
# Label file for 1999_330_grs.lbl could not be retrieved.
# Data file for 1999_331_grs.dat could not be retrieved.
# Label file for 1999_331_grs.lbl could not be retrieved.
# Data file for 1999_332_grs.dat could not be retrieved.
# Label file for 1999_332_grs.lbl could not be retrieved.
# Data file for 1999_333_grs.dat could not be retrieved.
# Label file for 1999_333_grs.lbl could not be retrieved.
# Data file for 1999_334_grs.dat could not be retrieved.
# Label file for 1999_334_grs.lbl could not be retrieved.
# Data file for 1999_335_grs.dat could not be retrieved.
# Label file for 1999_335_grs.lbl could not be retrieved.
# Data file for 1999_336_grs.dat could not be retrieved.
# Label file for 1999_336_grs.lbl could not be retrieved.
# Data file for 1999_337_grs.dat could not be retrieved.
# Label file for 1999_337_grs.lbl could not be retrieved.
# Data file for 1999_338_grs.dat could not be retrieved.
# Label file for 1999_338_grs.lbl could not be retrieved.
# Data file for 1999_339_grs.dat could not be retrieved.
# Label file for 1999_339_grs.lbl could not be retrieved.
# Data file for 1999_340_grs.dat could not be retrieved.
# Label file for 1999_340_grs.lbl could not be retrieved.
# Data file for 1999_341_grs.dat could not be retrieved.
# Label file for 1999_341_grs.lbl could not be retrieved.
# Data file for 1999_342_grs.dat could not be retrieved.
# Label file for 1999_342_grs.lbl could not be retrieved.
# Data file for 1999_343_grs.dat could not be retrieved.
# Label file for 1999_343_grs.lbl could not be retrieved.
# Data file for 1999_344_grs.dat could not be retrieved.
# Label file for 1999_344_grs.lbl could not be retrieved.
# Data file for 1999_345_grs.dat could not be retrieved.
# Label file for 1999_345_grs.lbl could not be retrieved.
# Data file for 1999_346_grs.dat could not be retrieved.
# Label file for 1999_346_grs.lbl could not be retrieved.
# Data file for 1999_347_grs.dat could not be retrieved.
# Label file for 1999_347_grs.lbl could not be retrieved.
# Data file for 1999_348_grs.dat could not be retrieved.
# Label file for 1999_348_grs.lbl could not be retrieved.
# Data file for 1999_349_grs.dat could not be retrieved.
# Label file for 1999_349_grs.lbl could not be retrieved.
# Data file for 1999_350_grs.dat could not be retrieved.
# Label file for 1999_350_grs.lbl could not be retrieved.
# Data file for 1999_351_grs.dat could not be retrieved.
# Label file for 1999_351_grs.lbl could not be retrieved.
# Data file for 1999_352_grs.dat could not be retrieved.
# Label file for 1999_352_grs.lbl could not be retrieved.
# Data file for 1999_353_grs.dat could not be retrieved.
# Label file for 1999_353_grs.lbl could not be retrieved.
# Data file for 1999_354_grs.dat could not be retrieved.
# Label file for 1999_354_grs.lbl could not be retrieved.
# Data file for 1999_355_grs.dat could not be retrieved.
# Label file for 1999_355_grs.lbl could not be retrieved.
# Data file for 1999_356_grs.dat could not be retrieved.
# Label file for 1999_356_grs.lbl could not be retrieved.
# Data file for 1999_357_grs.dat could not be retrieved.
# Label file for 1999_357_grs.lbl could not be retrieved.
# Data file for 1999_358_grs.dat could not be retrieved.
# Label file for 1999_358_grs.lbl could not be retrieved.
# Data file for 1999_359_grs.dat could not be retrieved.
# Label file for 1999_359_grs.lbl could not be retrieved.
# Data file for 1999_360_grs.dat could not be retrieved.
# Label file for 1999_360_grs.lbl could not be retrieved.
# Data file for 1999_361_grs.dat could not be retrieved.
# Label file for 1999_361_grs.lbl could not be retrieved.
# Data file for 1999_362_grs.dat could not be retrieved.
# Label file for 1999_362_grs.lbl could not be retrieved.
# Data file for 1999_363_grs.dat could not be retrieved.
# Label file for 1999_363_grs.lbl could not be retrieved.
# Data file for 1999_364_grs.dat could not be retrieved.
# Label file for 1999_364_grs.lbl could not be retrieved.
# Data file for 1999_365_grs.dat could not be retrieved.
# Label file for 1999_365_grs.lbl could not be retrieved.
# Data file for 1999_366_grs.dat could not be retrieved.
# Label file for 1999_366_grs.lbl could not be retrieved.
# Total time taken to retrive all data and label files: 2547.8225 seconds
# Total .dat files not found 174
# Total .lbl files not found 178

# %% [markdown]
# # Parsing .dat files
#
# The .dat files are parsed in accordance with the instructions and format specified in the respective .lbl file. To illustrate, we first parse the **1998_270_grs.dat** file which denotes the GRS data collected on Day 270 of 1998 by the Lunar Prospector. After parsing through the .dat file, a **Pandas Dataframe** is created which is used to plot and perform further calculations.

# %%
filename = "./Task1/1998_270_grs.lbl"
datafilename = "./Task1/1998_270_grs.dat"

# Define the record format for the label file
label_format = [
    ("PDS_VERSION_ID", "23s"),
    ("RECORD_TYPE", "23s"),
    ("RECORD_BYTES", "23s"),
    ("FILE_RECORDS", "23s"),
    ("^TABLE", "23s"),
    ("DATA_SET_NAME", "59s"),
    ("DATA_SET_ID", "33s"),
    ("PRODUCT_ID", "23s"),
    ("PRODUCT_TYPE", "23s"),
    ("PRODUCT_VERSION_ID", "23s"),
    ("SPACECRAFT_NAME", "23s"),
    ("INSTRUMENT_NAME", "23s"),
    ("TARGET_NAME", "23s"),
    ("START_TIME", "23s"),
    ("STOP_TIME", "23s"),
    ("SPACECRAFT_CLOCK_START_COUNT", "23s"),
    ("SPACECRAFT_CLOCK_STOP_COUNT", "23s"),
    ("PRODUCT_CREATION_TIME", "23s")
]

# Define the record format for the data file
data_format = [
    ("accepted_spectrum", "512f"),
    ("rejected_spectrum", "512f"),
    ("deadtime", "f"),
    ("overload", "f"),
    ("grs_temperature", "f"),
    ("earth_received_time", "f"),
    ("spacecraft_altitude", "f"),
    ("subspacecraft_latitude", "f"),
    ("subspacecraft_longitude", "f")
]

# Open the data file for reading
with open(filename, "r") as f:
    label = {}
    for line in f:
        # Ignoring all comments in the .lbl file.
        if line.strip() and not line.startswith("#"):
            # Splitting lines and reading values for corresponding labels
            parts = line.split("=", 1)
            if len(parts) == 2:
                key = parts[0].strip()
                value = parts[1].strip()
                label[key] = value

# Read the data file
with open(datafilename, "rb") as f:
    # Parse each data record in the file
    data = []
    for i in range(int(label["FILE_RECORDS"])):
        record = {}
        for field, format in data_format:
            bytes = f.read(struct.calcsize(format))
            value = struct.unpack(format, bytes)[0]
            # Separate condition for accepted and rejected spectrum as they 512 data items.
            if field == "accepted_spectrum" or field == "rejected_spectrum":
                value = struct.unpack(format, bytes)
            record[field] = value
        data.append(record)

# Print some information from the label and data
print("Data Set Name:", label["DATA_SET_NAME"])
print("Product ID:", label["PRODUCT_ID"])
print("Start Time:", label["START_TIME"])
print("Stop Time:", label["STOP_TIME"])
print("Number of Records:", len(data))

df = pd.DataFrame(data)
df
# Out:
# Data Set Name: "LP MOON GAMMA RAY SPECTROMETER 3 RDR V1.0"
# Product ID: "1998_270_GRS"
# Start Time: 1998-270T00:00:00
# Stop Time: 1998-270T23:59:59
# Number of Records: 2434
#                                       accepted_spectrum  \
# 0     (64.02674102783203, 13.172483444213867, 7.3601...
# 1     (71.24832153320312, 16.329853057861328, 6.2006...
# 2     (75.33775329589844, 14.223711013793945, 2.8263...
# 3     (66.99480438232422, 13.69210147857666, 2.24435...
# 4     (83.07652282714844, 18.389801025390625, 8.6971...
# ...                                                 ...
# 2429  (75.26776885986328, 13.090079307556152, 6.5458...
# 2430  (75.17789459228516, 12.126038551330566, 2.8355...
# 2431  (79.4575424194336, 14.664920806884766, 3.31126...
# 2432  (67.12801361083984, 14.736181259155273, 4.6537...
# 2433  (67.05589294433594, 12.82453727722168, 3.32525...
#
#                                       rejected_spectrum  deadtime  overload  \
# 0     (64.02674102783203, 13.172483444213867, 7.3601...  0.036275   19240.0
# 1     (71.24832153320312, 16.329853057861328, 6.2006...  0.036379   19470.0
# 2     (75.33775329589844, 14.223711013793945, 2.8263...  0.036232   19333.0
# 3     (66.99480438232422, 13.69210147857666, 2.24435...  0.035954   19481.0
# 4     (83.07652282714844, 18.389801025390625, 8.6971...  0.036298   19235.0
# ...                                                 ...       ...       ...
# 2429  (75.26776885986328, 13.090079307556152, 6.5458...  0.038344   20041.0
# 2430  (75.17789459228516, 12.126038551330566, 2.8355...  0.038190   19712.0
# 2431  (79.4575424194336, 14.664920806884766, 3.31126...  0.038392   19890.0
# 2432  (67.12801361083984, 14.736181259155273, 4.6537...  0.038206   19701.0
# 2433  (67.05589294433594, 12.82453727722168, 3.32525...  0.038266   19466.0
#
#       grs_temperature  earth_received_time  spacecraft_altitude  \
# 0          -29.462872           270.000458            94.548889
# 1          -29.462872           270.000824            94.397430
# 2          -29.462872           270.001190            94.250351
# 3          -29.244972           270.001556            94.106232
# 4          -29.027073           270.001953            93.965805
# ...               ...                  ...                  ...
# 2429       -29.027073           270.998230            90.229843
# 2430       -29.027073           270.998596            90.314163
# 2431       -29.027073           270.998993            90.410225
# 2432       -29.027073           270.999359            90.507782
# 2433       -28.594601           271.000092            90.725143
#
#       subspacecraft_latitude  subspacecraft_longitude
# 0                 -65.034149               295.419830
# 1                 -66.671982               295.401123
# 2                 -68.310600               295.380676
# 3                 -69.948906               295.357666
# 4                 -71.588005               295.331635
# ...                      ...                      ...
# 2429              -39.729458               102.430252
# 2430              -38.083675               102.428497
# 2431              -36.437691               102.426430
# 2432              -34.792377               102.424416
# 2433              -31.502739               102.419945
#
# [2434 rows x 9 columns]

# %%
import os

directory = './Task1'  # Replace with your directory path
files = os.listdir(directory)

dat_files = []
lbl_files = []
for file in files:
    if file.endswith('.dat'):
        dat_files.append(file)
    elif file.endswith('.lbl'):
        lbl_files.append(file)

# %%
data = []
for i in dat_files:
    print(f"Working on file {i}")
    if i[:-4] + ".lbl" in lbl_files:
        filename = f"./Task1/{i[:-4]}.lbl"
        datafilename = f"./Task1/{i}"
    else:
        continue

    # Define the record format for the label file
    label_format = [
        ("PDS_VERSION_ID", "23s"),
        ("RECORD_TYPE", "23s"),
        ("RECORD_BYTES", "23s"),
        ("FILE_RECORDS", "23s"),
        ("^TABLE", "23s"),
        ("DATA_SET_NAME", "59s"),
        ("DATA_SET_ID", "33s"),
        ("PRODUCT_ID", "23s"),
        ("PRODUCT_TYPE", "23s"),
        ("PRODUCT_VERSION_ID", "23s"),
        ("SPACECRAFT_NAME", "23s"),
        ("INSTRUMENT_NAME", "23s"),
        ("TARGET_NAME", "23s"),
        ("START_TIME", "23s"),
        ("STOP_TIME", "23s"),
        ("SPACECRAFT_CLOCK_START_COUNT", "23s"),
        ("SPACECRAFT_CLOCK_STOP_COUNT", "23s"),
        ("PRODUCT_CREATION_TIME", "23s")
    ]

    # Define the record format for the data file
    data_format = [
        ("accepted_spectrum", "512f"),
        ("rejected_spectrum", "512f"),
        ("deadtime", "f"),
        ("overload", "f"),
        ("grs_temperature", "f"),
        ("earth_received_time", "f"),
        ("spacecraft_altitude", "f"),
        ("subspacecraft_latitude", "f"),
        ("subspacecraft_longitude", "f")
    ]

    # Open the data file for reading
    with open(filename, "r") as f:
        label = {}
        for line in f:
            # Ignoring all comments in the .lbl file.
            if line.strip() and not line.startswith("#"):
                # Splitting lines and reading values for corresponding labels
                parts = line.split("=", 1)
                if len(parts) == 2:
                    key = parts[0].strip()
                    value = parts[1].strip()
                    label[key] = value

    # Read the data file
    with open(datafilename, "rb") as f:
        for i in range(int(label["FILE_RECORDS"])):
            record = {}
            for field, format in data_format:
                bytes = f.read(struct.calcsize(format))
                value = struct.unpack(format, bytes)[0]
                # Separate condition for accepted and rejected spectrum as they 512 data items.
                if field == "accepted_spectrum" or field == "rejected_spectrum":
                    value = struct.unpack(format, bytes)
                record[field] = value
            data.append(record)

df = pd.DataFrame(data)
df.head()
df.info()
df.to_csv("./Task1/cumulative_grs_data.csv", index = False)
# Out:
# Working on file 1998_016_grs.dat
# Working on file 1998_017_grs.dat
# Working on file 1998_018_grs.dat
# Working on file 1998_019_grs.dat
# Working on file 1998_020_grs.dat
# Working on file 1998_021_grs.dat
# Working on file 1998_022_grs.dat
# Working on file 1998_023_grs.dat
# Working on file 1998_024_grs.dat
# Working on file 1998_025_grs.dat
# Working on file 1998_026_grs.dat
# Working on file 1998_027_grs.dat
# Working on file 1998_028_grs.dat
# Working on file 1998_029_grs.dat
# Working on file 1998_030_grs.dat
# Working on file 1998_031_grs.dat
# Working on file 1998_032_grs.dat
# Working on file 1998_033_grs.dat
# Working on file 1998_034_grs.dat
# Working on file 1998_035_grs.dat
# Working on file 1998_036_grs.dat
# Working on file 1998_037_grs.dat
# Working on file 1998_038_grs.dat
# Working on file 1998_039_grs.dat
# Working on file 1998_040_grs.dat
# Working on file 1998_041_grs.dat
# Working on file 1998_042_grs.dat
# Working on file 1998_043_grs.dat
# Working on file 1998_044_grs.dat
# Working on file 1998_045_grs.dat
# Working on file 1998_046_grs.dat
# Working on file 1998_047_grs.dat
# Working on file 1998_049_grs.dat
# Working on file 1998_050_grs.dat
# Working on file 1998_051_grs.dat
# Working on file 1998_052_grs.dat
# Working on file 1998_053_grs.dat
# Working on file 1998_054_grs.dat
# Working on file 1998_055_grs.dat
# Working on file 1998_056_grs.dat
# Working on file 1998_057_grs.dat
# Working on file 1998_059_grs.dat
# Working on file 1998_060_grs.dat
# Working on file 1998_061_grs.dat
# Working on file 1998_062_grs.dat
# Working on file 1998_063_grs.dat
# Working on file 1998_064_grs.dat
# Working on file 1998_065_grs.dat
# Working on file 1998_066_grs.dat
# Working on file 1998_067_grs.dat
# Working on file 1998_068_grs.dat
# Working on file 1998_069_grs.dat
# Working on file 1998_070_grs.dat
# Working on file 1998_071_grs.dat
# Working on file 1998_072_grs.dat
# Working on file 1998_073_grs.dat
# Working on file 1998_074_grs.dat
# Working on file 1998_075_grs.dat
# Working on file 1998_076_grs.dat
# Working on file 1998_077_grs.dat
# Working on file 1998_078_grs.dat
# Working on file 1998_079_grs.dat
# Working on file 1998_080_grs.dat
# Working on file 1998_081_grs.dat
# Working on file 1998_082_grs.dat
# Working on file 1998_083_grs.dat
# Working on file 1998_084_grs.dat
# Working on file 1998_085_grs.dat
# Working on file 1998_086_grs.dat
# Working on file 1998_088_grs.dat
# Working on file 1998_089_grs.dat
# Working on file 1998_090_grs.dat
# Working on file 1998_091_grs.dat
# Working on file 1998_092_grs.dat
# Working on file 1998_093_grs.dat
# Working on file 1998_094_grs.dat
# Working on file 1998_095_grs.dat
# Working on file 1998_096_grs.dat
# Working on file 1998_097_grs.dat
# Working on file 1998_098_grs.dat
# Working on file 1998_099_grs.dat
# Working on file 1998_100_grs.dat
# Working on file 1998_101_grs.dat
# Working on file 1998_102_grs.dat
# Working on file 1998_103_grs.dat
# Working on file 1998_104_grs.dat
# Working on file 1998_105_grs.dat
# Working on file 1998_106_grs.dat
# Working on file 1998_107_grs.dat
# Working on file 1998_108_grs.dat
# Working on file 1998_109_grs.dat
# Working on file 1998_110_grs.dat
# Working on file 1998_116_grs.dat
# Working on file 1998_117_grs.dat
# Working on file 1998_118_grs.dat
# Working on file 1998_119_grs.dat
# Working on file 1998_124_grs.dat
# Working on file 1998_125_grs.dat
# Working on file 1998_126_grs.dat
# Working on file 1998_128_grs.dat
# Working on file 1998_129_grs.dat
# Working on file 1998_131_grs.dat
# Working on file 1998_132_grs.dat
# Working on file 1998_133_grs.dat
# Working on file 1998_134_grs.dat
# Working on file 1998_135_grs.dat
# Working on file 1998_136_grs.dat
# Working on file 1998_137_grs.dat
# Working on file 1998_138_grs.dat
# Working on file 1998_139_grs.dat
# Working on file 1998_140_grs.dat
# Working on file 1998_141_grs.dat
# Working on file 1998_142_grs.dat
# Working on file 1998_143_grs.dat
# Working on file 1998_144_grs.dat
# Working on file 1998_145_grs.dat
# Working on file 1998_146_grs.dat
# Working on file 1998_147_grs.dat
# Working on file 1998_148_grs.dat
# Working on file 1998_149_grs.dat
# Working on file 1998_150_grs.dat
# Working on file 1998_151_grs.dat
# Working on file 1998_152_grs.dat
# Working on file 1998_153_grs.dat
# Working on file 1998_154_grs.dat
# Working on file 1998_155_grs.dat
# Working on file 1998_156_grs.dat
# Working on file 1998_157_grs.dat
# Working on file 1998_158_grs.dat
# Working on file 1998_159_grs.dat
# Working on file 1998_160_grs.dat
# Working on file 1998_161_grs.dat
# Working on file 1998_162_grs.dat
# Working on file 1998_163_grs.dat
# Working on file 1998_164_grs.dat
# Working on file 1998_165_grs.dat
# Working on file 1998_166_grs.dat
# Working on file 1998_167_grs.dat
# Working on file 1998_168_grs.dat
# Working on file 1998_170_grs.dat
# Working on file 1998_171_grs.dat
# Working on file 1998_172_grs.dat
# Working on file 1998_173_grs.dat
# Working on file 1998_174_grs.dat
# Working on file 1998_175_grs.dat
# Working on file 1998_176_grs.dat
# Working on file 1998_177_grs.dat
# Working on file 1998_178_grs.dat
# Working on file 1998_179_grs.dat
# Working on file 1998_180_grs.dat
# Working on file 1998_181_grs.dat
# Working on file 1998_182_grs.dat
# Working on file 1998_183_grs.dat
# Working on file 1998_185_grs.dat
# Working on file 1998_186_grs.dat
# Working on file 1998_187_grs.dat
# Working on file 1998_188_grs.dat
# Working on file 1998_189_grs.dat
# Working on file 1998_190_grs.dat
# Working on file 1998_191_grs.dat
# Working on file 1998_192_grs.dat
# Working on file 1998_193_grs.dat
# Working on file 1998_194_grs.dat
# Working on file 1998_195_grs.dat
# Working on file 1998_196_grs.dat
# Working on file 1998_197_grs.dat
# Working on file 1998_198_grs.dat
# Working on file 1998_199_grs.dat
# Working on file 1998_200_grs.dat
# Working on file 1998_202_grs.dat
# Working on file 1998_203_grs.dat
# Working on file 1998_204_grs.dat
# Working on file 1998_205_grs.dat
# Working on file 1998_206_grs.dat
# Working on file 1998_207_grs.dat
# Working on file 1998_208_grs.dat
# Working on file 1998_209_grs.dat
# Working on file 1998_210_grs.dat
# Working on file 1998_211_grs.dat
# Working on file 1998_212_grs.dat
# Working on file 1998_213_grs.dat
# Working on file 1998_214_grs.dat
# Working on file 1998_215_grs.dat
# Working on file 1998_216_grs.dat
# Working on file 1998_217_grs.dat
# Working on file 1998_218_grs.dat
# Working on file 1998_219_grs.dat
# Working on file 1998_220_grs.dat
# Working on file 1998_221_grs.dat
# Working on file 1998_222_grs.dat
# Working on file 1998_223_grs.dat
# Working on file 1998_224_grs.dat
# Working on file 1998_225_grs.dat
# Working on file 1998_226_grs.dat
# Working on file 1998_227_grs.dat
# Working on file 1998_228_grs.dat
# Working on file 1998_229_grs.dat
# Working on file 1998_230_grs.dat
# Working on file 1998_231_grs.dat
# Working on file 1998_232_grs.dat
# Working on file 1998_233_grs.dat
# Working on file 1998_234_grs.dat
# Working on file 1998_243_grs.dat
# Working on file 1998_244_grs.dat
# Working on file 1998_245_grs.dat
# Working on file 1998_246_grs.dat
# Working on file 1998_247_grs.dat
# Working on file 1998_248_grs.dat
# Working on file 1998_249_grs.dat
# Working on file 1998_250_grs.dat
# Working on file 1998_251_grs.dat
# Working on file 1998_252_grs.dat
# Working on file 1998_253_grs.dat
# Working on file 1998_254_grs.dat
# Working on file 1998_255_grs.dat
# Working on file 1998_256_grs.dat
# Working on file 1998_257_grs.dat
# Working on file 1998_258_grs.dat
# Working on file 1998_259_grs.dat
# Working on file 1998_260_grs.dat
# Working on file 1998_261_grs.dat
# Working on file 1998_262_grs.dat
# Working on file 1998_263_grs.dat
# Working on file 1998_264_grs.dat
# Working on file 1998_265_grs.dat
# Working on file 1998_266_grs.dat
# Working on file 1998_267_grs.dat
# Working on file 1998_268_grs.dat
# Working on file 1998_269_grs.dat
# Working on file 1998_270_grs.dat
# Working on file 1998_271_grs.dat
# Working on file 1998_272_grs.dat
# Working on file 1998_273_grs.dat
# Working on file 1998_277_grs.dat
# Working on file 1998_278_grs.dat
# Working on file 1998_280_grs.dat
# Working on file 1998_281_grs.dat
# Working on file 1998_282_grs.dat
# Working on file 1998_283_grs.dat
# Working on file 1998_284_grs.dat
# Working on file 1998_285_grs.dat
# Working on file 1998_286_grs.dat
# Working on file 1998_287_grs.dat
# Working on file 1998_288_grs.dat
# Working on file 1998_289_grs.dat
# Working on file 1998_290_grs.dat
# Working on file 1998_291_grs.dat
# Working on file 1998_293_grs.dat
# Working on file 1998_294_grs.dat
# Working on file 1998_295_grs.dat
# Working on file 1998_296_grs.dat
# Working on file 1998_297_grs.dat
# Working on file 1998_298_grs.dat
# Working on file 1998_299_grs.dat
# Working on file 1998_300_grs.dat
# Working on file 1998_302_grs.dat
# Working on file 1998_303_grs.dat
# Working on file 1998_304_grs.dat
# Working on file 1998_305_grs.dat
# Working on file 1998_306_grs.dat
# Working on file 1998_307_grs.dat
# Working on file 1998_308_grs.dat
# Working on file 1998_309_grs.dat
# Working on file 1998_313_grs.dat
# Working on file 1998_314_grs.dat
# Working on file 1998_315_grs.dat
# Working on file 1998_316_grs.dat
# Working on file 1998_317_grs.dat
# Working on file 1998_318_grs.dat
# Working on file 1998_323_grs.dat
# Working on file 1998_324_grs.dat
# Working on file 1998_325_grs.dat
# Working on file 1998_326_grs.dat
# Working on file 1998_327_grs.dat
# Working on file 1998_328_grs.dat
# Working on file 1998_329_grs.dat
# Working on file 1998_330_grs.dat
# Working on file 1998_331_grs.dat
# Working on file 1998_332_grs.dat
# Working on file 1998_333_grs.dat
# Working on file 1998_334_grs.dat
# Working on file 1998_335_grs.dat
# Working on file 1998_336_grs.dat
# Working on file 1998_337_grs.dat
# Working on file 1998_338_grs.dat
# Working on file 1998_339_grs.dat
# Working on file 1998_340_grs.dat
# Working on file 1998_341_grs.dat
# Working on file 1998_342_grs.dat
# Working on file 1998_343_grs.dat
# Working on file 1998_344_grs.dat
# Working on file 1998_345_grs.dat
# Working on file 1998_346_grs.dat
# Working on file 1998_347_grs.dat
# Working on file 1998_348_grs.dat
# Working on file 1998_349_grs.dat
# Working on file 1998_350_grs.dat
# Working on file 1998_351_grs.dat
# Working on file 1998_352_grs.dat
# Working on file 1998_353_grs.dat
# Working on file 1998_354_grs.dat
# Working on file 1998_355_grs.dat
# Working on file 1998_356_grs.dat
# Working on file 1998_357_grs.dat
# Working on file 1998_358_grs.dat
# Working on file 1998_359_grs.dat
# Working on file 1998_360_grs.dat
# Working on file 1998_361_grs.dat
# Working on file 1998_362_grs.dat
# Working on file 1998_363_grs.dat
# Working on file 1998_364_grs.dat
# Working on file 1998_365_grs.dat
# Working on file 1999_001_grs.dat
# Working on file 1999_002_grs.dat
# Working on file 1999_003_grs.dat
# Working on file 1999_004_grs.dat
# Working on file 1999_005_grs.dat
# Working on file 1999_006_grs.dat
# Working on file 1999_007_grs.dat
# Working on file 1999_008_grs.dat
# Working on file 1999_009_grs.dat
# Working on file 1999_010_grs.dat
# Working on file 1999_011_grs.dat
# Working on file 1999_012_grs.dat
# Working on file 1999_013_grs.dat
# Working on file 1999_014_grs.dat
# Working on file 1999_015_grs.dat
# Working on file 1999_016_grs.dat
# Working on file 1999_017_grs.dat
# Working on file 1999_018_grs.dat
# Working on file 1999_019_grs.dat
# Working on file 1999_020_grs.dat
# Working on file 1999_025_grs.dat
# Working on file 1999_026_grs.dat
# Working on file 1999_027_grs.dat
# Working on file 1999_028_grs.dat
# Working on file 1999_029_grs.dat
# Working on file 1999_030_grs.dat
# Working on file 1999_031_grs.dat
# Working on file 1999_032_grs.dat
# Working on file 1999_033_grs.dat
# Working on file 1999_034_grs.dat
# Working on file 1999_035_grs.dat
# Working on file 1999_036_grs.dat
# Working on file 1999_037_grs.dat
# Working on file 1999_038_grs.dat
# Working on file 1999_039_grs.dat
# Working on file 1999_040_grs.dat
# Working on file 1999_041_grs.dat
# Working on file 1999_042_grs.dat
# Working on file 1999_043_grs.dat
# Working on file 1999_044_grs.dat
# Working on file 1999_045_grs.dat
# Working on file 1999_046_grs.dat
# Working on file 1999_047_grs.dat
# Working on file 1999_048_grs.dat
# Working on file 1999_049_grs.dat
# Working on file 1999_050_grs.dat
# Working on file 1999_051_grs.dat
# Working on file 1999_052_grs.dat
# Working on file 1999_053_grs.dat
# Working on file 1999_054_grs.dat
# Working on file 1999_055_grs.dat
# Working on file 1999_056_grs.dat
# Working on file 1999_057_grs.dat
# Working on file 1999_058_grs.dat
# Working on file 1999_059_grs.dat
# Working on file 1999_060_grs.dat
# Working on file 1999_061_grs.dat
# Working on file 1999_062_grs.dat
# Working on file 1999_063_grs.dat
# Working on file 1999_064_grs.dat
# Working on file 1999_065_grs.dat
# Working on file 1999_066_grs.dat
# Working on file 1999_067_grs.dat
# Working on file 1999_068_grs.dat
# Working on file 1999_069_grs.dat
# Working on file 1999_070_grs.dat
# Working on file 1999_071_grs.dat
# Working on file 1999_072_grs.dat
# Working on file 1999_073_grs.dat
# Working on file 1999_074_grs.dat
# Working on file 1999_075_grs.dat
# Working on file 1999_076_grs.dat
# Working on file 1999_077_grs.dat
# Working on file 1999_078_grs.dat
# Working on file 1999_079_grs.dat
# Working on file 1999_080_grs.dat
# Working on file 1999_081_grs.dat
# Working on file 1999_082_grs.dat
# Working on file 1999_083_grs.dat
# Working on file 1999_084_grs.dat
# Working on file 1999_085_grs.dat
# Working on file 1999_086_grs.dat
# Working on file 1999_087_grs.dat
# Working on file 1999_088_grs.dat
# Working on file 1999_089_grs.dat
# Working on file 1999_090_grs.dat
# Working on file 1999_091_grs.dat
# Working on file 1999_092_grs.dat
# Working on file 1999_093_grs.dat
# Working on file 1999_094_grs.dat
# Working on file 1999_095_grs.dat
# Working on file 1999_096_grs.dat
# Working on file 1999_097_grs.dat
# Working on file 1999_098_grs.dat
# Working on file 1999_099_grs.dat
# Working on file 1999_100_grs.dat
# Working on file 1999_101_grs.dat
# Working on file 1999_102_grs.dat
# Working on file 1999_103_grs.dat
# Working on file 1999_104_grs.dat
# Working on file 1999_105_grs.dat
# Working on file 1999_106_grs.dat
# Working on file 1999_108_grs.dat
# Working on file 1999_109_grs.dat
# Working on file 1999_110_grs.dat
# Working on file 1999_111_grs.dat
# Working on file 1999_112_grs.dat
# Working on file 1999_113_grs.dat
# Working on file 1999_114_grs.dat
# Working on file 1999_116_grs.dat
# Working on file 1999_117_grs.dat
# Working on file 1999_118_grs.dat
# Working on file 1999_119_grs.dat
# Working on file 1999_120_grs.dat
# Working on file 1999_121_grs.dat
# Working on file 1999_122_grs.dat
# Working on file 1999_123_grs.dat
# Working on file 1999_128_grs.dat
# Working on file 1999_129_grs.dat
# Working on file 1999_130_grs.dat
# Working on file 1999_131_grs.dat
# Working on file 1999_132_grs.dat
# Working on file 1999_133_grs.dat
# Working on file 1999_134_grs.dat
# Working on file 1999_135_grs.dat
# Working on file 1999_136_grs.dat
# Working on file 1999_137_grs.dat
# Working on file 1999_138_grs.dat
# Working on file 1999_139_grs.dat
# Working on file 1999_140_grs.dat
# Working on file 1999_141_grs.dat
# Working on file 1999_142_grs.dat
# Working on file 1999_143_grs.dat
# Working on file 1999_144_grs.dat
# Working on file 1999_145_grs.dat
# Working on file 1999_146_grs.dat
# Working on file 1999_147_grs.dat
# Working on file 1999_148_grs.dat
# Working on file 1999_149_grs.dat
# Working on file 1999_150_grs.dat
# Working on file 1999_151_grs.dat
# Working on file 1999_152_grs.dat
# Working on file 1999_159_grs.dat
# Working on file 1999_160_grs.dat
# Working on file 1999_161_grs.dat
# Working on file 1999_162_grs.dat
# Working on file 1999_163_grs.dat
# Working on file 1999_164_grs.dat
# Working on file 1999_165_grs.dat
# Working on file 1999_166_grs.dat
# Working on file 1999_168_grs.dat
# Working on file 1999_169_grs.dat
# Working on file 1999_170_grs.dat
# Working on file 1999_171_grs.dat
# Working on file 1999_172_grs.dat
# Working on file 1999_173_grs.dat
# Working on file 1999_174_grs.dat
# Working on file 1999_175_grs.dat
# Working on file 1999_176_grs.dat
# Working on file 1999_177_grs.dat
# Working on file 1999_178_grs.dat
# Working on file 1999_179_grs.dat
# Working on file 1999_180_grs.dat
# Working on file 1999_181_grs.dat
# Working on file 1999_182_grs.dat
# Working on file 1999_183_grs.dat
# Working on file 1999_184_grs.dat
# Working on file 1999_185_grs.dat
# Working on file 1999_186_grs.dat
# Working on file 1999_187_grs.dat
# Working on file 1999_188_grs.dat
# Working on file 1999_189_grs.dat
# Working on file 1999_190_grs.dat
# Working on file 1999_191_grs.dat
# Working on file 1999_192_grs.dat
# Working on file 1999_193_grs.dat
# Working on file 1999_194_grs.dat
# Working on file 1999_195_grs.dat
# Working on file 1999_196_grs.dat
# Working on file 1999_197_grs.dat
# Working on file 1999_198_grs.dat
# Working on file 1999_199_grs.dat
# Working on file 1999_200_grs.dat
# Working on file 1999_201_grs.dat
# Working on file 1999_202_grs.dat
# Working on file 1999_203_grs.dat
# Working on file 1999_204_grs.dat
# Working on file 1999_205_grs.dat
# Working on file 1999_206_grs.dat
# Working on file 1999_207_grs.dat
# Working on file 1999_208_grs.dat
# Working on file 1999_209_grs.dat
